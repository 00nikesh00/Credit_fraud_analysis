# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import tqdm

# %%
data = pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
# sns.pairplot(data, hue="Class")

# %%
plt.figure(figsize = (10,10))
plt.title("Heatmap for correleation")
heatmap = sns.heatmap(data=data.corr())
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_list1 = scaler.fit_transform(data[['Time']])
scaled_list2 = scaler.fit_transform(data[['Amount']])

# %%
data[['Time']] = scaled_list1
data[['Amount']]= scaled_list2

# %%
data.head(5)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0  0.239599  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676 -1.514654  ...    0.247998  0.771679  0.909412
# 3  0.237609  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321
# 4  0.592941 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.050379e-14  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std    1.000002e+00  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min   -1.996583e+00 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%   -8.552120e-01 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%   -2.131453e-01  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    9.372174e-01  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    1.642058e+00  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
plt.scatter(x = data['Amount'], y = data['Class'])

# %%
data_zero = data.loc[data['Class'] == 0]
data_one = data.loc[data['Class'] == 1]
data_zero = data_zero.sample(n = 500, random_state = 1)
#data_zero = data_zero.sample(n = 500, random_state = 0)

# %%
df = data_zero.append(data_one)

# %%
# from sklearn.utils import shuffle
# df = shuffle(df)

# %%
df = df.sample(frac=1).reset_index(drop = True)

# %%
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -0.096463  2.222140 -0.804846 -1.009062 -0.714829 -0.598079 -0.572235
# 1  1.075347  1.555291  0.673431 -1.880368  4.394118  0.815187 -0.741956
# 2 -0.380682 -1.536326  2.223649 -0.387143 -0.279654  1.098826  0.737699
# 3  1.109482 -1.611877 -0.408410 -3.829762  6.249462 -3.360922  1.147964
# 4  0.809322  0.090926  0.251606 -1.935605 -0.800226  1.842519 -1.643831
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0 -0.863684 -0.150388  1.356792  ...    0.008280  0.243024  0.216083
# 1  0.745521 -0.248754 -1.112567  ...   -0.308340 -1.198921  0.118647
# 2 -0.558894 -2.016298 -1.544805  ...   -1.359023  0.124102 -0.334983
# 3  1.858425  0.474858 -3.838399  ...    1.245582  0.616383  2.251439
# 4  1.975271 -0.667419 -0.568470  ...    0.630938  1.765937  0.221998
#
#         V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
columns = 'Time V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11 V12 V13 V14 V15 V16 V17 V18 V19 V20 V21 V22 V23 V24 V25 V26 V27 V28 Amount'.split()

# %%
# x = df.loc[:,columns].values
# y = df.loc[:,['Class']].values

# %%
# x

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 2)
# principleComponents = pca.fit_transform(x)
# dfx = pd.DataFrame(data = principleComponents, columns = ['Feature1', 'Feature2'])

# %%
import numpy as np
fig = plt.figure(figsize=(8,8))
plt.plot(np.cumsum(PCA().fit(df).explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance explained')
plt.show()

# %%
x = df.drop('Class', axis = 1)
y = df['Class']

# %%
from sklearn.decomposition import PCA
x_pca = PCA(n_components = 2, random_state = 1).fit_transform(x)

# %%
# dff = pd.concat([dfx, df[['Class']]], axis = 1)

# %%
# dff.Class = dff.Class.astype(str)

# %%
# d = dff[['Class']]

# %%
#d.dtypes

# %%
#(d == '1').sum()

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
targets = ['0', '1']
colors = ['red', 'green']
for target, color in zip(targets,colors):
    indicesToKeep = dff['Class'] == target
    ax.scatter(dff.loc[indicesToKeep, 'Feature1'], dff.loc[indicesToKeep,'Feature2'], c = color, s = 20)
ax.legend(targets)
ax.grid()

# %%
x = dff.iloc[:,[0,1]].values
y = dff.iloc[:,2].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 22)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 2)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=2, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[103,   0],
#        [  7,  89]], dtype=int64)

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train
x1, x2 = np.meshgrid(np.arange(start=x_set[:,0].min()-1, stop=x_set[:,0].max()+1, step = 0.01),
                     np.arange(start=x_set[:,1].min()-1, stop=x_set[:,1].max()+1, step = 0.01))
plt.contourf(x1, x2, classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
            alpha = 0.75, cmap = ListedColormap(('red','green')))
plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j,0], x_set[y_set == j, 1],
               c = ListedColormap(('blue','green'))(i), label = j)
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support
avg_precision = precision_recall_fscore_support(y_test, y_pred, average = 'weighted')
print('Average precision-recall score: ', avg_precision)
# Out:
# Average precision-recall score:  (0.9670625856555505, 0.964824120603015, 0.9647366384007334, None)
